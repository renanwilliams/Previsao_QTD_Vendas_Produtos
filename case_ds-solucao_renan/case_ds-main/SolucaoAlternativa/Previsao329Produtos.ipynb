# %%
# Carregando a base de dados
import pandas as pd
import sqlite3

con = sqlite3.connect("../database.sqlite3")
df = pd.read_sql_query("SELECT * from vendas", con)

con.close()

# %%
# Utilizado para identificar produtos com ciclos completos
df_grupo = pd.read_csv('../df_grupo.csv',index_col='Unnamed: 0')

# %%
# Eliminando variáveis estáticas
df = df.drop(['DES_CATEGORIA_MATERIAL','DES_MARCA_MATERIAL','FLG_CAMPANHA_MKT_E','FLG_CAMPANHA_MKT_F'],axis=1)

# %%
# Definindo base de treino e base de teste
df_train = df[(df['COD_MATERIAL'].isin(df_grupo.index)) & (~df['COD_CICLO'].isin([202016,202017,202101]))].sort_values(by='COD_CICLO')
df_test = df[(df['COD_MATERIAL'].isin(df_grupo.index)) & (df['COD_CICLO'].isin([202016,202017,202101]))].sort_values(by='COD_CICLO')

# %%
# Função necessária para processamento das variáveis indicadores.
def preprocessamento_indicadores(x):
    if x>= 0.5:
        return 1
    else:
        return 0

# %%
# Bibliotecas para processo de modelagem
from sklearn.tree import DecisionTreeRegressor
from tqdm import tqdm
from sklearn.model_selection import TimeSeriesSplit
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
# Feature Engineering, Cross-Validation

produto = {}

for i in tqdm(df_grupo.Grupo.index):
    df_aux = df_train[df_train['COD_MATERIAL'] == i]
    df_aux = df_aux.reset_index(drop=True)
    df_aux['ANO'] = df_aux['COD_CICLO'].apply(lambda x: int(str(x)[:4]))
    df_aux['CICLO'] = df_aux['COD_CICLO'].apply(lambda x: int(str(x)[4:]))
    df_aux['FLG_CAMPANHA_MKT_A'] = df_aux['FLG_CAMPANHA_MKT_A'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_B'] = df_aux['FLG_CAMPANHA_MKT_B'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_C'] = df_aux['FLG_CAMPANHA_MKT_C'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_D'] = df_aux['FLG_CAMPANHA_MKT_D'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['PCT_DESCONTO'].fillna(0,inplace=True)
    df_aux = df_aux.drop(['COD_CICLO','COD_MATERIAL'],axis=1)
    
    
    X = df_aux.drop('QT_VENDA',axis=1)
    y = df_aux['QT_VENDA']

    # Definindo o método de Cross-Validation que será utilizado na otimização dos parâmetros
    cv = TimeSeriesSplit(n_splits=3)
    # RMSE em cada fold
    cv_scores = np.empty(3)
    
    for idx, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        model = DecisionTreeRegressor()
        model.fit(X_train,y_train)

        preds = model.predict(X_test)
        cv_scores[idx] = mean_squared_error(y_test, preds,squared=False)
    
    produto[i] = [np.mean(cv_scores),model.fit(X,y)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 329/329 [00:10<00:00, 31.00it/s]

# %%
# Produto, Performance do Modelo no Cross-Validation, Modelo treinado
produto
# Out:
# {153066: [236142.25438296722, DecisionTreeRegressor()],
#  420294: [12246.264994311254, DecisionTreeRegressor()],
#  432552: [5350.382299376507, DecisionTreeRegressor()],
#  177306: [14161.882421114058, DecisionTreeRegressor()],
#  170478: [7875.00515154222, DecisionTreeRegressor()],
#  125556: [14498.486724428489, DecisionTreeRegressor()],
#  125424: [30354.70803472582, DecisionTreeRegressor()],
#  153096: [118836.40393943973, DecisionTreeRegressor()],
#  420282: [19974.71200531103, DecisionTreeRegressor()],
#  166128: [27775.50251537527, DecisionTreeRegressor()],
#  432588: [36602.032361299054, DecisionTreeRegressor()],
#  432576: [15728.468655127183, DecisionTreeRegressor()],
#  432582: [9412.857559446134, DecisionTreeRegressor()],
#  153084: [152060.94152019627, DecisionTreeRegressor()],
#  420288: [21839.107603067718, DecisionTreeRegressor()],
#  170370: [13628.146333788567, DecisionTreeRegressor()],
#  432528: [11148.249638353946, DecisionTreeRegressor()],
#  420510: [34978.61184572204, DecisionTreeRegressor()],
#  128136: [363.0749109540828, DecisionTreeRegressor()],
#  128142: [115859.87223167277, DecisionTreeRegressor()],
#  166464: [198493.49801383412, DecisionTreeRegressor()],
#  128148: [70135.26857883163, DecisionTreeRegressor()],
#  420516: [34409.89956514991, DecisionTreeRegressor()],
#  432516: [36373.8705815607, DecisionTreeRegressor()],
#  420492: [57615.51298000213, DecisionTreeRegressor()],
#  152982: [277904.2295056932, DecisionTreeRegressor()],
#  432534: [52137.91031425415, DecisionTreeRegressor()],
#  127920: [16123.122555667052, DecisionTreeRegressor()],
#  153000: [54873.046480240264, DecisionTreeRegressor()],
#  420504: [32521.75139269758, DecisionTreeRegressor()],
#  172902: [13967.327990719403, DecisionTreeRegressor()],
#  166458: [79020.86761041252, DecisionTreeRegressor()],
#  432540: [13666.93465466024, DecisionTreeRegressor()],
#  128118: [822.1531514961944, DecisionTreeRegressor()],
#  432498: [2498.8114715403435, DecisionTreeRegressor()],
#  432666: [8411.163068647826, DecisionTreeRegressor()],
#  432660: [16518.542735479685, DecisionTreeRegressor()],
#  166110: [14159.8694967215, DecisionTreeRegressor()],
#  153918: [64927.89728135689, DecisionTreeRegressor()],
#  432630: [27260.26054850504, DecisionTreeRegressor()],
#  123846: [24817.722300812573, DecisionTreeRegressor()],
#  154992: [75456.43330031364, DecisionTreeRegressor()],
#  179958: [29783.985346060716, DecisionTreeRegressor()],
#  432684: [10406.896620853278, DecisionTreeRegressor()],
#  170466: [26014.71359811668, DecisionTreeRegressor()],
#  177420: [54512.968625102454, DecisionTreeRegressor()],
#  154158: [21085.975243129014, DecisionTreeRegressor()],
#  432672: [10463.557300184828, DecisionTreeRegressor()],
#  123840: [39176.195454359164, DecisionTreeRegressor()],
#  125286: [411690.91696095373, DecisionTreeRegressor()],
#  432600: [59267.6799766729, DecisionTreeRegressor()],
#  153510: [37254.424888262234, DecisionTreeRegressor()],
#  420276: [10323.68901724713, DecisionTreeRegressor()],
#  432594: [12275.267096754511, DecisionTreeRegressor()],
#  432624: [20406.117574866705, DecisionTreeRegressor()],
#  170376: [19216.96990908611, DecisionTreeRegressor()],
#  420270: [10803.35510575579, DecisionTreeRegressor()],
#  432618: [18560.79542728957, DecisionTreeRegressor()],
#  177396: [682109.1906042437, DecisionTreeRegressor()],
#  153522: [15947.584024420392, DecisionTreeRegressor()],
#  173766: [49978.7128533461, DecisionTreeRegressor()],
#  432696: [12786.583536678605, DecisionTreeRegressor()],
#  420948: [60963.55419625592, DecisionTreeRegressor()],
#  170574: [7539.039540517089, DecisionTreeRegressor()],
#  152682: [12721.696723810526, DecisionTreeRegressor()],
#  420960: [23720.820961530942, DecisionTreeRegressor()],
#  420936: [138328.88640577465, DecisionTreeRegressor()],
#  166746: [6678.490088477321, DecisionTreeRegressor()],
#  170364: [11169.16495651946, DecisionTreeRegressor()],
#  174312: [33829.950696372594, DecisionTreeRegressor()],
#  431490: [73554.19283275613, DecisionTreeRegressor()],
#  109428: [13155.877257241831, DecisionTreeRegressor()],
#  431652: [39440.489827792684, DecisionTreeRegressor()],
#  420972: [7171.032053363812, DecisionTreeRegressor()],
#  152646: [70747.60008757099, DecisionTreeRegressor()],
#  423024: [12391.277706590658, DecisionTreeRegressor()],
#  431004: [10808.10005918111, DecisionTreeRegressor()],
#  133728: [77938.42280392472, DecisionTreeRegressor()],
#  152634: [135330.73676960476, DecisionTreeRegressor()],
#  423180: [33170.69731273874, DecisionTreeRegressor()],
#  152670: [21862.256671088184, DecisionTreeRegressor()],
#  170622: [15197.048587474108, DecisionTreeRegressor()],
#  133614: [57196.95118212056, DecisionTreeRegressor()],
#  152664: [14423.84787207011, DecisionTreeRegressor()],
#  421020: [23352.630434543637, DecisionTreeRegressor()],
#  133722: [51412.91811236174, DecisionTreeRegressor()],
#  152658: [69372.25994864029, DecisionTreeRegressor()],
#  422478: [67423.67198277521, DecisionTreeRegressor()],
#  176694: [50211.86598418786, DecisionTreeRegressor()],
#  420534: [30494.282990319607, DecisionTreeRegressor()],
#  152778: [39892.56421046272, DecisionTreeRegressor()],
#  152784: [23272.206486311657, DecisionTreeRegressor()],
#  420546: [11429.795590271418, DecisionTreeRegressor()],
#  166506: [88603.28014241038, DecisionTreeRegressor()],
#  152766: [18708.022153193193, DecisionTreeRegressor()],
#  420564: [11447.870527601961, DecisionTreeRegressor()],
#  172806: [8482.895786961923, DecisionTreeRegressor()],
#  432396: [43329.576756236354, DecisionTreeRegressor()],
#  432492: [4326.729803918396, DecisionTreeRegressor()],
#  128466: [14403.707798105925, DecisionTreeRegressor()],
#  432402: [27778.427169300117, DecisionTreeRegressor()],
#  170484: [9956.107581652694, DecisionTreeRegressor()],
#  152796: [45766.07681548494, DecisionTreeRegressor()],
#  420528: [21371.260911173726, DecisionTreeRegressor()],
#  152760: [24368.765265944112, DecisionTreeRegressor()],
#  166590: [105612.70736676315, DecisionTreeRegressor()],
#  130854: [39762.800278374714, DecisionTreeRegressor()],
#  420900: [61874.84428711506, DecisionTreeRegressor()],
#  152700: [68111.5494742364, DecisionTreeRegressor()],
#  420930: [74669.51672330432, DecisionTreeRegressor()],
#  420630: [20051.388351787045, DecisionTreeRegressor()],
#  170496: [37517.0078368044, DecisionTreeRegressor()],
#  420576: [13486.802010133266, DecisionTreeRegressor()],
#  177210: [8012.243561698378, DecisionTreeRegressor()],
#  130734: [8428.585895300619, DecisionTreeRegressor()],
#  432708: [27720.604766772547, DecisionTreeRegressor()],
#  435132: [35344.984851625435, DecisionTreeRegressor()],
#  160890: [19394.424328083205, DecisionTreeRegressor()],
#  170406: [13616.609286468141, DecisionTreeRegressor()],
#  177900: [12246.52133897133, DecisionTreeRegressor()],
#  170388: [20487.617587527184, DecisionTreeRegressor()],
#  177792: [12555.101424711102, DecisionTreeRegressor()],
#  173718: [50201.66836824637, DecisionTreeRegressor()],
#  157272: [4980.222452946699, DecisionTreeRegressor()],
#  177912: [38350.76817994846, DecisionTreeRegressor()],
#  433764: [19475.192976675768, DecisionTreeRegressor()],
#  118344: [52808.58915364388, DecisionTreeRegressor()],
#  177990: [4572.777235561404, DecisionTreeRegressor()],
#  155916: [9646.081247929129, DecisionTreeRegressor()],
#  118638: [80891.02625643127, DecisionTreeRegressor()],
#  177594: [75448.51195148182, DecisionTreeRegressor()],
#  61326: [85669.52980455104, DecisionTreeRegressor()],
#  434592: [5293.668487984328, DecisionTreeRegressor()],
#  177906: [35198.24534380349, DecisionTreeRegressor()],
#  434124: [25330.43741856544, DecisionTreeRegressor()],
#  177816: [46773.39157113495, DecisionTreeRegressor()],
#  177882: [18395.28303348601, DecisionTreeRegressor()],
#  173652: [165510.9741570517, DecisionTreeRegressor()],
#  170394: [20987.9105134974, DecisionTreeRegressor()],
#  103644: [15572.32419955921, DecisionTreeRegressor()],
#  177840: [15710.976270893023, DecisionTreeRegressor()],
#  103650: [10795.96292347178, DecisionTreeRegressor()],
#  158556: [15626.495673441292, DecisionTreeRegressor()],
#  435258: [7358.760213072065, DecisionTreeRegressor()],
#  177894: [28913.478222945592, DecisionTreeRegressor()],
#  435252: [5182.24591675673, DecisionTreeRegressor()],
#  435318: [12950.953053192583, DecisionTreeRegressor()],
#  157314: [11042.429992916013, DecisionTreeRegressor()],
#  113724: [16049.001656995131, DecisionTreeRegressor()],
#  170400: [18144.916238512113, DecisionTreeRegressor()],
#  155910: [3595.5667181930617, DecisionTreeRegressor()],
#  97716: [2198.446034045533, DecisionTreeRegressor()],
#  177516: [6868.228495946544, DecisionTreeRegressor()],
#  164454: [59414.71894298203, DecisionTreeRegressor()],
#  173112: [81067.51703116571, DecisionTreeRegressor()],
#  177462: [1369.8066903520469, DecisionTreeRegressor()],
#  432726: [7515.6348729393785, DecisionTreeRegressor()],
#  432750: [10013.586108523317, DecisionTreeRegressor()],
#  170454: [15903.532184772195, DecisionTreeRegressor()],
#  173754: [5951.661667099859, DecisionTreeRegressor()],
#  178836: [23308.215491159557, DecisionTreeRegressor()],
#  97770: [2572.0570822108916, DecisionTreeRegressor()],
#  179406: [8374.544537897711, DecisionTreeRegressor()],
#  432714: [4575.534918584354, DecisionTreeRegressor()],
#  170340: [88979.96737772984, DecisionTreeRegressor()],
#  173106: [54796.54822023518, DecisionTreeRegressor()],
#  122622: [11500.378797500287, DecisionTreeRegressor()],
#  179478: [81264.25771814358, DecisionTreeRegressor()],
#  432720: [21575.054045955443, DecisionTreeRegressor()],
#  170460: [22224.510006376982, DecisionTreeRegressor()],
#  177456: [1383.8311464917297, DecisionTreeRegressor()],
#  170448: [15931.650124848327, DecisionTreeRegressor()],
#  433530: [32325.918431200727, DecisionTreeRegressor()],
#  155472: [120167.57802767846, DecisionTreeRegressor()],
#  118680: [33466.703450146655, DecisionTreeRegressor()],
#  118806: [1993.2968849774943, DecisionTreeRegressor()],
#  433710: [43352.53345924902, DecisionTreeRegressor()],
#  433194: [29230.362723132246, DecisionTreeRegressor()],
#  170382: [18259.062161346865, DecisionTreeRegressor()],
#  178092: [25345.560240792165, DecisionTreeRegressor()],
#  142824: [22824.317334718344, DecisionTreeRegressor()],
#  429420: [25655.080471156267, DecisionTreeRegressor()],
#  443130: [27700.0601335345, DecisionTreeRegressor()],
#  426276: [32448.299267050093, DecisionTreeRegressor()],
#  142770: [21251.56706509474, DecisionTreeRegressor()],
#  429624: [103682.42297066264, DecisionTreeRegressor()],
#  426102: [16442.31637396535, DecisionTreeRegressor()],
#  142764: [16313.935659371638, DecisionTreeRegressor()],
#  443124: [22669.294778440668, DecisionTreeRegressor()],
#  151122: [15798.780377438174, DecisionTreeRegressor()],
#  174822: [27992.341016747665, DecisionTreeRegressor()],
#  425640: [67604.01948082236, DecisionTreeRegressor()],
#  174816: [19201.72568977365, DecisionTreeRegressor()],
#  428652: [146984.9326686929, DecisionTreeRegressor()],
#  427512: [22314.214791187027, DecisionTreeRegressor()],
#  150660: [22555.416217611433, DecisionTreeRegressor()],
#  427530: [10185.49065249106, DecisionTreeRegressor()],
#  443136: [12694.665487294753, DecisionTreeRegressor()],
#  142914: [10173.295768501579, DecisionTreeRegressor()],
#  150678: [11195.552512705872, DecisionTreeRegressor()],
#  174810: [120985.23169884068, DecisionTreeRegressor()],
#  427536: [52283.394662882085, DecisionTreeRegressor()],
#  150684: [20506.748944423565, DecisionTreeRegressor()],
#  142848: [24391.069897687314, DecisionTreeRegressor()],
#  142836: [5452.70036685821, DecisionTreeRegressor()],
#  71082: [1066.6464485083764, DecisionTreeRegressor()],
#  427974: [14673.094123257708, DecisionTreeRegressor()],
#  427962: [4996.991728640881, DecisionTreeRegressor()],
#  142842: [9939.549600898417, DecisionTreeRegressor()],
#  174654: [86886.04240692216, DecisionTreeRegressor()],
#  430026: [54477.74346886365, DecisionTreeRegressor()],
#  169512: [121087.35881280707, DecisionTreeRegressor()],
#  430092: [33163.17602687582, DecisionTreeRegressor()],
#  425178: [50019.490489663294, DecisionTreeRegressor()],
#  430170: [74212.39512941138, DecisionTreeRegressor()],
#  430278: [31105.41622373032, DecisionTreeRegressor()],
#  151950: [83009.7855574127, DecisionTreeRegressor()],
#  425184: [25784.487970651837, DecisionTreeRegressor()],
#  425172: [40329.22566052065, DecisionTreeRegressor()],
#  140982: [446.09242040590584, DecisionTreeRegressor()],
#  151938: [58547.69313006974, DecisionTreeRegressor()],
#  169620: [108211.62163659453, DecisionTreeRegressor()],
#  174828: [22294.044643090634, DecisionTreeRegressor()],
#  170352: [6040.053456507026, DecisionTreeRegressor()],
#  425634: [29647.900586662854, DecisionTreeRegressor()],
#  171810: [38502.145768971895, DecisionTreeRegressor()],
#  425628: [18880.750909150167, DecisionTreeRegressor()],
#  151134: [13051.99681103627, DecisionTreeRegressor()],
#  171816: [15874.60740492367, DecisionTreeRegressor()],
#  425382: [26704.34368439697, DecisionTreeRegressor()],
#  430080: [134924.93101684478, DecisionTreeRegressor()],
#  170334: [82493.29196352612, DecisionTreeRegressor()],
#  174702: [64716.65925561377, DecisionTreeRegressor()],
#  427200: [13368.380800806915, DecisionTreeRegressor()],
#  443256: [4997.77062788843, DecisionTreeRegressor()],
#  170328: [23781.651529596344, DecisionTreeRegressor()],
#  427278: [10777.581792934763, DecisionTreeRegressor()],
#  148578: [26159.06674358224, DecisionTreeRegressor()],
#  443250: [6323.727965942529, DecisionTreeRegressor()],
#  427272: [6772.915522725659, DecisionTreeRegressor()],
#  427026: [20647.352290641295, DecisionTreeRegressor()],
#  427254: [36384.99880441844, DecisionTreeRegressor()],
#  171786: [14693.3223081283, DecisionTreeRegressor()],
#  174696: [23653.90654220541, DecisionTreeRegressor()],
#  150228: [18637.87929550269, DecisionTreeRegressor()],
#  427086: [3864.835809393604, DecisionTreeRegressor()],
#  427056: [32397.1904615255, DecisionTreeRegressor()],
#  427110: [37209.81572024125, DecisionTreeRegressor()],
#  427122: [36002.106265028786, DecisionTreeRegressor()],
#  427164: [13430.101736834362, DecisionTreeRegressor()],
#  427044: [13233.378879018563, DecisionTreeRegressor()],
#  150168: [14545.703245498144, DecisionTreeRegressor()],
#  171780: [31260.29316247454, DecisionTreeRegressor()],
#  427128: [11147.135085534954, DecisionTreeRegressor()],
#  427050: [35140.541486413706, DecisionTreeRegressor()],
#  427014: [23945.63567063159, DecisionTreeRegressor()],
#  69198: [342137.6006120465, DecisionTreeRegressor()],
#  426870: [41990.42171546726, DecisionTreeRegressor()],
#  150630: [12135.448032454724, DecisionTreeRegressor()],
#  427380: [186848.51239397182, DecisionTreeRegressor()],
#  443142: [19795.173234637055, DecisionTreeRegressor()],
#  426810: [149923.8896019362, DecisionTreeRegressor()],
#  171750: [21017.003589609983, DecisionTreeRegressor()],
#  171798: [53751.252647706155, DecisionTreeRegressor()],
#  427386: [24174.66508233731, DecisionTreeRegressor()],
#  170298: [57647.948264814266, DecisionTreeRegressor()],
#  427506: [29033.832620569407, DecisionTreeRegressor()],
#  150654: [7487.098633792321, DecisionTreeRegressor()],
#  427374: [76213.56122130367, DecisionTreeRegressor()],
#  170346: [20050.350498703916, DecisionTreeRegressor()],
#  427392: [21498.131764569676, DecisionTreeRegressor()],
#  174672: [47938.08348330546, DecisionTreeRegressor()],
#  170310: [96637.00883669622, DecisionTreeRegressor()],
#  148572: [42064.57035386934, DecisionTreeRegressor()],
#  427284: [6245.204334474006, DecisionTreeRegressor()],
#  427008: [57799.63661566304, DecisionTreeRegressor()],
#  171792: [19740.3465556127, DecisionTreeRegressor()],
#  427290: [8423.202430922536, DecisionTreeRegressor()],
#  427296: [19918.25159722438, DecisionTreeRegressor()],
#  443208: [10582.055030237121, DecisionTreeRegressor()],
#  427350: [242409.64507883938, DecisionTreeRegressor()],
#  426990: [10593.9691629662, DecisionTreeRegressor()],
#  427338: [13310.829714602047, DecisionTreeRegressor()],
#  174732: [4992.115929800617, DecisionTreeRegressor()],
#  150618: [7330.793358690421, DecisionTreeRegressor()],
#  443202: [12073.139616105107, DecisionTreeRegressor()],
#  427332: [59412.16117166718, DecisionTreeRegressor()],
#  170316: [68724.15973194495, DecisionTreeRegressor()],
#  427002: [8144.019082895657, DecisionTreeRegressor()],
#  430788: [21108.71241990702, DecisionTreeRegressor()],
#  152262: [37921.566501203866, DecisionTreeRegressor()],
#  423654: [53382.79298428388, DecisionTreeRegressor()],
#  424458: [16768.650044007365, DecisionTreeRegressor()],
#  152598: [70080.77625909205, DecisionTreeRegressor()],
#  424476: [49637.957520145894, DecisionTreeRegressor()],
#  176076: [39411.67689376316, DecisionTreeRegressor()],
#  136194: [50621.09903244506, DecisionTreeRegressor()],
#  430776: [41083.26661235347, DecisionTreeRegressor()],
#  136050: [121727.38103263093, DecisionTreeRegressor()],
#  423774: [5214.062895835898, DecisionTreeRegressor()],
#  136062: [10071.976261215385, DecisionTreeRegressor()],
#  430770: [37740.91010735964, DecisionTreeRegressor()],
#  152268: [251258.0029150085, DecisionTreeRegressor()],
#  430782: [35473.22735219058, DecisionTreeRegressor()],
#  423660: [6183.431925764938, DecisionTreeRegressor()],
#  136044: [67167.74177083328, DecisionTreeRegressor()],
#  136206: [65890.68428201007, DecisionTreeRegressor()],
#  424446: [54459.758589669735, DecisionTreeRegressor()],
#  424452: [19459.401022618244, DecisionTreeRegressor()],
#  136056: [6483.030358022614, DecisionTreeRegressor()],
#  135330: [78987.62240139979, DecisionTreeRegressor()],
#  174318: [47445.82057369762, DecisionTreeRegressor()],
#  152016: [34385.582144735556, DecisionTreeRegressor()],
#  424482: [33877.43229143872, DecisionTreeRegressor()],
#  135246: [34094.09962493012, DecisionTreeRegressor()],
#  430290: [6324.565295002688, DecisionTreeRegressor()],
#  430998: [12718.036365658962, DecisionTreeRegressor()],
#  423192: [12480.888432528876, DecisionTreeRegressor()],
#  424488: [41779.721809412054, DecisionTreeRegressor()],
#  152226: [10542.330272070714, DecisionTreeRegressor()],
#  430992: [11054.259858280677, DecisionTreeRegressor()],
#  424506: [26879.00016288366, DecisionTreeRegressor()],
#  135336: [99026.48817382853, DecisionTreeRegressor()],
#  442926: [20047.91899294681, DecisionTreeRegressor()],
#  430836: [9700.344939490828, DecisionTreeRegressor()],
#  425166: [35015.941307282825, DecisionTreeRegressor()],
#  175590: [71933.44107780229, DecisionTreeRegressor()],
#  423348: [21251.24975001486, DecisionTreeRegressor()],
#  430794: [30175.170189483102, DecisionTreeRegressor()]}

# %%
# Previsão da variável target no conjunto de dados de teste, ciclos: 202016,202017,202101.
for i in tqdm(df_grupo.Grupo.index):
    
    df_aux = df_test[df_test['COD_MATERIAL'] == i]
    df_aux = df_aux.reset_index(drop=True)
    df_aux['ANO'] = df_aux['COD_CICLO'].apply(lambda x: int(str(x)[:4]))
    df_aux['CICLO'] = df_aux['COD_CICLO'].apply(lambda x: int(str(x)[4:]))
    df_aux['FLG_CAMPANHA_MKT_A'] = df_aux['FLG_CAMPANHA_MKT_A'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_B'] = df_aux['FLG_CAMPANHA_MKT_B'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_C'] = df_aux['FLG_CAMPANHA_MKT_C'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['FLG_CAMPANHA_MKT_D'] = df_aux['FLG_CAMPANHA_MKT_D'].apply(lambda x: preprocessamento_indicadores(x))
    df_aux['PCT_DESCONTO'].fillna(0,inplace=True)
    df_aux = df_aux.drop(['COD_CICLO','COD_MATERIAL','QT_VENDA'],axis=1)
    
    for j, k in zip(df_test[df_test['COD_MATERIAL'] == i].index, [0,1,2]):
        df_test.at[j,'QT_VENDA'] = produto[i][1].predict(df_aux.loc[k,:].values.reshape(1,-1))[0]
# Out:
#   0%|                                                                                          | 0/329 [00:00<?, ?it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#   3%|██▍                                                                              | 10/329 [00:00<00:03, 87.78it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#   6%|████▉                                                                            | 20/329 [00:00<00:03, 90.60it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#   9%|███████▋                                                                         | 31/329 [00:00<00:03, 92.61it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#  12%|██████████                                                                       | 41/329 [00:00<00:03, 94.55it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#  16%|████████████▊                                                                    | 52/329 [00:00<00:02, 96.40it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#  19%|███████████████▎                                                                 | 62/329 [00:00<00:02, 96.49it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# ...
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#  96%|█████████████████████████████████████████████████████████████████████████████   | 317/329 [00:03<00:00, 97.41it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
#  99%|███████████████████████████████████████████████████████████████████████████████▌| 327/329 [00:03<00:00, 97.08it/s]C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\renan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# 100%|████████████████████████████████████████████████████████████████████████████████| 329/329 [00:03<00:00, 96.27it/s]

# %%
df_test.to_excel('df_test_produtos_com_ciclos_completos.xlsx')
